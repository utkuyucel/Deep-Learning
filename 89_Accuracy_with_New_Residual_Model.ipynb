# %% [markdown]
# <a href="https://colab.research.google.com/github/utkuyucel/Deep-Learning/blob/master/89_Accuracy_with_New_Residual_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from keras.utils import plot_model
import os

(X_train, y_train),(X_test, y_test) = tf.keras.datasets.cifar10.load_data()

X_train = X_train.astype("float32")
X_test = X_test.astype("float32")

X_test /= 255
X_train /= 255

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %%
try:
  device_name = os.environ['COLAB_TPU_ADDR']
  TPU_ADDRESS = 'grpc://' + device_name
  print('Found TPU at: {}'.format(TPU_ADDRESS))

except KeyError:
  print('TPU not found')
# Out:
# Found TPU at: grpc://10.32.232.42:8470

# %%
def short(X_input, F1, F2, F3, F4):
  
  X = tf.keras.layers.Conv2D(F1, (3,3), strides = (1,1), padding = "same")(X_input)
  X = tf.keras.layers.BatchNormalization()(X)
  X = tf.keras.layers.Activation("relu")(X)
  
  X = tf.keras.layers.Conv2D(F2, (3,3), strides = (1,1), padding = "same")(X)
  X = tf.keras.layers.BatchNormalization()(X)
  X = tf.keras.layers.Activation("relu")(X)

  X = tf.keras.layers.Conv2D(F3, (3,3), strides = (1,1), padding = "same")(X)
  X = tf.keras.layers.BatchNormalization()(X)
  X = tf.keras.layers.Activation("relu")(X)
  
  X = tf.keras.layers.Conv2D(F4, (3,3), strides = (1,1), padding = "same")(X)
  X = tf.keras.layers.BatchNormalization()(X)
  
  
  L = tf.keras.layers.concatenate([X,X_input])
  
  L = tf.keras.layers.Activation("relu")(L)
  
  L = tf.keras.layers.MaxPooling2D((2,2))(L)
  
  return L

# %%
def model(X_input):
  
  X_input = tf.keras.layers.Input(X_input)
  
  X = tf.keras.layers.ZeroPadding2D((3,3))(X_input)
  
  X = short(X, 64, 64, 64, 128)
  X = short(X, 128, 128, 128, 256)
  X = short(X, 256, 256, 256, 512) 
  
  
  FC = tf.keras.layers.AveragePooling2D(2,2)(X)
  
  F = tf.keras.layers.Flatten()(FC)
  
  FC = tf.keras.layers.Dense(10, activation = "softmax")(F)
  
  
  model = tf.keras.models.Model(inputs = X_input, outputs = FC)
  
  return model

# %%
model = model((32,32,3))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 38, 38, 64)   1792        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1 (BatchNo (None, 38, 38, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 38, 38, 64)   0           batch_normalization_v1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 38, 38, 64)   36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_1 (Batch (None, 38, 38, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 38, 38, 64)   0           batch_normalization_v1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 38, 38, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_2 (Batch (None, 38, 38, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 38, 38, 64)   0           batch_normalization_v1_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 38, 38, 128)  73856       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_3 (Batch (None, 38, 38, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 38, 38, 131)  0           batch_normalization_v1_3[0][0]
#                                                                  zero_padding2d[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 38, 38, 131)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 19, 19, 131)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 19, 19, 128)  151040      max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_4 (Batch (None, 19, 19, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 19, 19, 128)  0           batch_normalization_v1_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 19, 19, 128)  147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_5 (Batch (None, 19, 19, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 19, 19, 128)  0           batch_normalization_v1_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 19, 19, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_6 (Batch (None, 19, 19, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 19, 19, 128)  0           batch_normalization_v1_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 19, 19, 256)  295168      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_7 (Batch (None, 19, 19, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 19, 19, 387)  0           batch_normalization_v1_7[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 19, 19, 387)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 9, 9, 387)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 9, 9, 256)    891904      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_8 (Batch (None, 9, 9, 256)    1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 9, 9, 256)    0           batch_normalization_v1_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 9, 9, 256)    590080      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_9 (Batch (None, 9, 9, 256)    1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 9, 9, 256)    0           batch_normalization_v1_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 9, 9, 256)    590080      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_10 (Batc (None, 9, 9, 256)    1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 9, 9, 256)    0           batch_normalization_v1_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 9, 9, 512)    1180160     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_11 (Batc (None, 9, 9, 512)    2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 9, 9, 899)    0           batch_normalization_v1_11[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 9, 9, 899)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 899)    0           activation_11[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 2, 2, 899)    0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3596)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           35970       flatten[0][0]
# ==================================================================================================
# Total params: 4,188,034
# Trainable params: 4,183,554
# Non-trainable params: 4,480
# __________________________________________________________________________________________________

# %%
from matplotlib import pyplot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

plot_model(model, to_file='model.png')
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
import os
tpu_model = tf.contrib.tpu.keras_to_tpu_model(
    model,
    strategy=tf.contrib.tpu.TPUDistributionStrategy(
        tf.contrib.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])
    )
)

#tpu_model.load_weights("./MNIST_TPU_1024.h5")


tpu_model.compile(
    optimizer=tf.train.AdamOptimizer(learning_rate=1e-3, ),
    loss=tf.keras.losses.categorical_crossentropy,
    metrics=['accuracy']
)

def train_gen(batch_size):
  while True:
    offset = np.random.randint(0, X_train.shape[0] - batch_size)
    yield X_train[offset:offset+batch_size], y_train[offset:offset + batch_size]
    

history = tpu_model.fit_generator(
    train_gen(1024),
    epochs=50,
    steps_per_epoch=100,
)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:Querying Tensorflow master (grpc://10.32.232.42:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 15857078998064548614)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 9038906979929784105)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 10956493310684821193)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 3497181705391349341)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 17886613599479991425)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 9564264920155947266)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 10410114647881559723)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 17679599249501829677)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 18077964352498678606)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 4401076907480037614)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 16577123562650964791)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.
# Epoch 1/50
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(128,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(128, 32, 32, 3), dtype=tf.float32, name='input_1_10'), TensorSpec(shape=(128, 10), dtype=tf.float32, name='dense_target_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for input_1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/tpu/python/tpu/keras_support.py:302: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 11.756829023361206 secs
# INFO:tensorflow:Setting weights on TPU model.
# 100/100 [==============================] - 51s 508ms/step - loss: 1.7268 - acc: 0.4288
# Epoch 2/50
# 100/100 [==============================] - 23s 231ms/step - loss: 0.9084 - acc: 0.6785
# Epoch 3/50
# 100/100 [==============================] - 23s 229ms/step - loss: 0.6064 - acc: 0.7885
# Epoch 4/50
# 100/100 [==============================] - 23s 230ms/step - loss: 0.4161 - acc: 0.8572
# Epoch 5/50
# 100/100 [==============================] - 23s 229ms/step - loss: 0.3153 - acc: 0.8923
# Epoch 6/50
# 100/100 [==============================] - 23s 232ms/step - loss: 0.2271 - acc: 0.9223
# Epoch 7/50
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1581 - acc: 0.9462
# Epoch 8/50
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1066 - acc: 0.9649
# Epoch 9/50
# 100/100 [==============================] - 23s 230ms/step - loss: 0.0756 - acc: 0.9751
# Epoch 10/50
# 100/100 [==============================] - 23s 232ms/step - loss: 0.0584 - acc: 0.9802
# Epoch 11/50
# 100/100 [==============================] - 23s 234ms/step - loss: 0.0429 - acc: 0.9864
# Epoch 12/50
# 100/100 [==============================] - 23s 231ms/step - loss: 0.0314 - acc: 0.9901
# Epoch 13/50
# 100/100 [==============================] - 23s 231ms/step - loss: 0.0333 - acc: 0.9887
# Epoch 14/50
# 100/100 [==============================] - 23s 234ms/step - loss: 0.0289 - acc: 0.9906
# Epoch 15/50
# 100/100 [==============================] - 23s 232ms/step - loss: 0.0106 - acc: 0.9972
# Epoch 16/50
# 100/100 [==============================] - 23s 232ms/step - loss: 0.0201 - acc: 0.9937
# Epoch 17/50
# 100/100 [==============================] - 23s 229ms/step - loss: 0.0380 - acc: 0.9867
# Epoch 18/50
# 100/100 [==============================] - 23s 232ms/step - loss: 0.0374 - acc: 0.9876
# Epoch 19/50
# 100/100 [==============================] - 23s 234ms/step - loss: 0.0137 - acc: 0.9959
# Epoch 20/50
# 100/100 [==============================] - 23s 229ms/step - loss: 0.0143 - acc: 0.9954
# Epoch 21/50
# 100/100 [==============================] - 23s 233ms/step - loss: 0.0225 - acc: 0.9930
# Epoch 22/50
# 100/100 [==============================] - 23s 231ms/step - loss: 0.0167 - acc: 0.9946
# Epoch 23/50
# 100/100 [==============================] - 23s 230ms/step - loss: 0.0208 - acc: 0.9929
# Epoch 24/50
# 100/100 [==============================] - 23s 229ms/step - loss: 0.0145 - acc: 0.9952
# Epoch 25/50
# 100/100 [==============================] - 23s 229ms/step - loss: 0.0205 - acc: 0.9931
# Epoch 26/50
# 100/100 [==============================] - 23s 227ms/step - loss: 0.0241 - acc: 0.9917
# Epoch 27/50
# 100/100 [==============================] - 23s 229ms/step - loss: 0.0151 - acc: 0.9947
# Epoch 28/50
# 100/100 [==============================] - 23s 230ms/step - loss: 0.0128 - acc: 0.9958
# Epoch 29/50
# 100/100 [==============================] - 23s 232ms/step - loss: 0.0157 - acc: 0.9947
# Epoch 30/50
# 100/100 [==============================] - 23s 229ms/step - loss: 0.0250 - acc: 0.9915
# Epoch 31/50
# 100/100 [==============================] - 23s 230ms/step - loss: 0.0152 - acc: 0.9950
# Epoch 32/50
# 100/100 [==============================] - 23s 231ms/step - loss: 0.0051 - acc: 0.9984
# Epoch 33/50
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0044 - acc: 0.9987
# Epoch 34/50
# 100/100 [==============================] - 23s 229ms/step - loss: 0.0020 - acc: 0.9995
# Epoch 35/50
# 100/100 [==============================] - 24s 236ms/step - loss: 0.0088 - acc: 0.9970
# Epoch 36/50
# 100/100 [==============================] - 23s 232ms/step - loss: 0.0382 - acc: 0.9869
# Epoch 37/50
# 100/100 [==============================] - 23s 228ms/step - loss: 0.0388 - acc: 0.9871
# Epoch 38/50
# 100/100 [==============================] - 23s 230ms/step - loss: 0.0228 - acc: 0.9925
# Epoch 39/50
# 100/100 [==============================] - 23s 233ms/step - loss: 0.0090 - acc: 0.9971
# Epoch 40/50
# 100/100 [==============================] - 23s 229ms/step - loss: 0.0027 - acc: 0.9992
# Epoch 41/50
# 100/100 [==============================] - 23s 229ms/step - loss: 7.6412e-04 - acc: 0.9998
# Epoch 42/50
# 100/100 [==============================] - 23s 234ms/step - loss: 2.4404e-04 - acc: 1.0000
# Epoch 43/50
# 100/100 [==============================] - 23s 229ms/step - loss: 1.8643e-04 - acc: 1.0000
# Epoch 44/50
# 100/100 [==============================] - 23s 229ms/step - loss: 4.5352e-05 - acc: 1.0000
# Epoch 45/50
# 100/100 [==============================] - 23s 229ms/step - loss: 2.7029e-05 - acc: 1.0000
# Epoch 46/50
# 100/100 [==============================] - 24s 236ms/step - loss: 3.0227e-05 - acc: 1.0000
# Epoch 47/50
# 100/100 [==============================] - 23s 228ms/step - loss: 1.8468e-05 - acc: 1.0000
# Epoch 48/50
# 100/100 [==============================] - 23s 229ms/step - loss: 1.5806e-05 - acc: 1.0000
# Epoch 49/50
# 100/100 [==============================] - 23s 235ms/step - loss: 1.3270e-05 - acc: 1.0000
# Epoch 50/50
# 100/100 [==============================] - 23s 230ms/step - loss: 1.2227e-05 - acc: 1.0000

# %%
tpu_model.save_weights('./MNIST_TPU_1024.h5', overwrite=True)
# Out:
# INFO:tensorflow:Copying TPU weights to the CPU

# %%
tpu_model.evaluate(X_test, y_test, steps = 100)
# Out:
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(1250,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(1250, 32, 32, 3), dtype=tf.float32, name='input_1_10'), TensorSpec(shape=(1250, 10), dtype=tf.float32, name='dense_target_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for input_1
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 11.020620107650757 secs
# 100/100 [==============================] - 91s 908ms/step - loss: 0.6681 - acc: 0.8904
# [0.6681042909622192, 0.8904]

# %%
LABEL_NAMES = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']


cpu_model = tpu_model.sync_to_cpu()

from matplotlib import pyplot
# %matplotlib inline

def plot_predictions(images, predictions):
  n = images.shape[0]
  nc = int(np.ceil(n / 4))
  f, axes = pyplot.subplots(nc, 4)
  for i in range(nc * 4):
    y = i // 4
    x = i % 4
    axes[x, y].axis('off')
    
    label = LABEL_NAMES[np.argmax(predictions[i])]
    confidence = np.max(predictions[i])
    if i > n:
      continue
    axes[x, y].imshow(images[i])
    axes[x, y].text(0.5, 0.5, label + '\n%.3f' % confidence, fontsize=14)

  pyplot.gcf().set_size_inches(8, 8)  

plot_predictions(np.squeeze(X_test[:16]), 
                 tpu_model.predict(X_test[:16]))
# Out:
# INFO:tensorflow:Copying TPU weights to the CPU
# INFO:tensorflow:New input shapes; (re-)compiling: mode=infer (# of cores 8), [TensorSpec(shape=(2, 32, 32, 3), dtype=tf.float32, name='input_1_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for input_1
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 5.545764923095703 secs
